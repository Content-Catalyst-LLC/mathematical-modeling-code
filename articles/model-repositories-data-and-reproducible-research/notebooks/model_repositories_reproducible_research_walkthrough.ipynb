# %% [markdown]
# # Model Repositories, Data, and Reproducible Research\n\nThis notebook demonstrates how repository artifacts, data provenance, reproducibility manifests, and model cards can be treated as auditable modeling objects.

# %% [markdown]
# $$Y = R(D,\\theta,C,E,V)$$\n\n$$(D,\\theta,C,E,V) \\longrightarrow (Y,Q,M)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom model_repositories_reproducible_research.core import load_expected_artifacts, artifact_inventory\nexpected = load_expected_artifacts(ARTICLE_ROOT / 'data' / 'expected_repository_artifacts.csv')\nartifact_inventory(ARTICLE_ROOT, expected)[:3]
