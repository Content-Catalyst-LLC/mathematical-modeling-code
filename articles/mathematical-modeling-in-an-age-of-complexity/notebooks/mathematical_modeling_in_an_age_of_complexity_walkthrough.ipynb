# %% [markdown]
# # Mathematical Modeling in an Age of Complexity\n\nThis notebook demonstrates how complexity model registers, scenario reviews, fragility scores, robust values, adaptive trigger flags, and governance cards can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$x_{t+1}=F(x_t,u_t,\\theta,\\epsilon_t)$$\n\n$$x_t \\geq \\tau \\Rightarrow \\text{regime shift}$$\n\n$$\\mathcal{M}=\\{M_1,M_2,\\ldots,M_k\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_an_age_of_complexity.core import load_complexity_scenarios, evaluate_scenario, complexity_summary\nscenarios = load_complexity_scenarios(ARTICLE_ROOT / 'data' / 'complexity_scenarios.csv')\nrows = [evaluate_scenario(scenario) for scenario in scenarios]\ncomplexity_summary(rows)
