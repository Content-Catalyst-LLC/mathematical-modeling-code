# %% [markdown]
# # Equations, Inequalities, and Model Logic\n\nThis notebook demonstrates how formal statements can be represented as reviewable model logic.

# %% [markdown]
# $$M=\\{E,I,D,L\\}$$\n\n$$\\mathcal{F}=\\{x\\in D:h_j(x,\\theta)=0,\\ g_i(x,\\theta)\\leq0\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom equations_inequalities_model_logic.core import load_scenarios, simulate_logic, summarize_logic\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'logic_scenarios.csv')\nrows = simulate_logic(scenarios[0])\nsummarize_logic(rows)
