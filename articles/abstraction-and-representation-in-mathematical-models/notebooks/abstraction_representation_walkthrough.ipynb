# %% [markdown]
# # Abstraction and Representation in Mathematical Models\n\nThis notebook demonstrates how a resource system is abstracted into an aggregate stock-flow representation and reviewed through an omitted-detail register.

# %% [markdown]
# $$S_{t+1}=\\min(K,\\max(0,S_t+I_t-D_t-L_t))$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom abstraction_representation.core import load_scenarios, simulate_stock_flow, summarize_stock_flow\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'stock_flow_scenarios.csv')\nrows = simulate_stock_flow(scenarios[0])\nsummarize_stock_flow(rows)
