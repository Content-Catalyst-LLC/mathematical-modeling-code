# %% [markdown]
# # Continuity, Discontinuity, and Structural Breaks\n\nThis notebook demonstrates finite-difference diagnostics for jumps, slope changes, and structural-break candidates in a synthetic piecewise system.

# %% [markdown]
# $$\\lim_{x\\to a} f(x)=f(a)$$\n\nContinuity means nearby inputs produce nearby outputs and the limiting value agrees with the function value.

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom continuity_structural_breaks.core import piecewise_system, diagnose_breaks\nxs = [i * 0.25 for i in range(41)]\nys = [piecewise_system(x) for x in xs]\n[row for row in diagnose_breaks(xs, ys) if row.flag != 'ok']
