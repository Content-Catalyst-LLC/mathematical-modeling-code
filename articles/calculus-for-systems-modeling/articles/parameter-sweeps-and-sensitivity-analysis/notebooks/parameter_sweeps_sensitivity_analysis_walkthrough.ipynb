# %% [markdown]
# # Parameter Sweeps and Sensitivity Analysis
#
# Placeholder for one-at-a-time sweeps, grid sweeps, local sensitivity, elasticity, response surfaces, robustness review, and parameter governance.

# %% [markdown]
# $$y=f(\theta)$$
# $$S_i=\frac{\partial y}{\partial \theta_i}$$
# $$E_i=\frac{\partial y}{\partial \theta_i}\cdot\frac{\theta_i}{y}$$
