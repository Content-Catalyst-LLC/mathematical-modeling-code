# %% [markdown]
# # Infrastructure Flow and Capacity Dynamics
#
# Flow rates, capacity constraints, queues, bottlenecks, buffers, maintenance, resilience, and governance.

# %% [markdown]
# $$\frac{dQ}{dt}=A(t)-D(t)$$
# $$u(t)=\frac{A(t)}{C(t)}$$
# $$F_{out}(t)\leq C(t)$$
