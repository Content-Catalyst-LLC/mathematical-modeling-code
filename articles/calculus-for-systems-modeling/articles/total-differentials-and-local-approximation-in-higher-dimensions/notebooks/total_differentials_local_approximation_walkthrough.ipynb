# %% [markdown]
# # Total Differentials and Local Approximation in Higher Dimensions
#
# Placeholder for total differential audits, tangent-plane approximations, feasible movement, and approximation-error diagnostics.

# %% [markdown]
# $$df=\nabla f(\mathbf{x})\cdot d\mathbf{x}$$
