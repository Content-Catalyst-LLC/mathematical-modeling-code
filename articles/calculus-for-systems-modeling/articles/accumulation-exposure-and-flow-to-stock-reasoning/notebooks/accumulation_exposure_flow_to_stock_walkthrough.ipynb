# %% [markdown]
# # Accumulation, Exposure, and Flow-to-Stock Reasoning
#
# This notebook demonstrates inflow-outflow accounting, stock change, cumulative exposure, population-weighted exposure, gross-versus-net reporting, unit checks, and measurement-window review.

# %% [markdown]
# $$S(t)=S(t_0)+\int_{t_0}^{t}(I(\tau)-O(\tau))\,d\tau$$
