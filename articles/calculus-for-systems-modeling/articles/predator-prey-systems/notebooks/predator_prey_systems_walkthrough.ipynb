# %% [markdown]
# # Case Study: Predator-Prey Systems
#
# Lotka-Volterra dynamics, nullclines, phase planes, functional responses, harvesting, stochasticity, calibration, and identifiability.

# %% [markdown]
# $$\frac{dx}{dt}=\alpha x-\beta xy$$
# $$\frac{dy}{dt}=\delta xy-\gamma y$$
# $$(x^*,y^*)=\left(\frac{\gamma}{\delta},\frac{\alpha}{\beta}\right)$$
