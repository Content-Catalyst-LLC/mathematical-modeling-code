# %% [markdown]
# # Derivatives and Rates of Change
#
# This notebook demonstrates average rates, finite-difference derivative estimates, elasticity, and convergence diagnostics.

# %% [markdown]
# $$f'(a)=\lim_{h\to 0}\frac{f(a+h)-f(a)}{h}$$
