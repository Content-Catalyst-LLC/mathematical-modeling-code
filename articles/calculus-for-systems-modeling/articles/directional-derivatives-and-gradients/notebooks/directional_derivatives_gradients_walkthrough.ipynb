# %% [markdown]
# # Directional Derivatives and Gradients
#
# Placeholder for gradient diagnostics, unit directions, feasible movement, contour interpretation, and local approximation checks.

# %% [markdown]
# $$D_{\mathbf{u}}f(\mathbf{x})=\nabla f(\mathbf{x})\cdot\mathbf{u}$$
