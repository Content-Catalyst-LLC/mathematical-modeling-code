# %% [markdown]
# # The Quotient Rule and Relative Change
#
# This notebook demonstrates numerator and denominator effects, quotient-rule decomposition, and relative-rate identity checks.

# %% [markdown]
# $$\frac{d}{dx}\left(\frac{f(x)}{g(x)}\right)=\frac{f'(x)g(x)-f(x)g'(x)}{g(x)^2}$$
