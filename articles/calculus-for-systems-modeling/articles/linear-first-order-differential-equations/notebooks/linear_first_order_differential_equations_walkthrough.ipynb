# %% [markdown]
# # Linear First-Order Differential Equations
#
# Placeholder for standard form, integrating factors, input-loss balance, equilibrium, transients, Euler comparison, and model governance.

# %% [markdown]
# $$\frac{dy}{dt}+p(t)y=q(t)$$
