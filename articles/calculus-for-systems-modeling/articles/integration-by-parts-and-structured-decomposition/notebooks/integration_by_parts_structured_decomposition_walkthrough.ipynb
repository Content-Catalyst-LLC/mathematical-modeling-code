# %% [markdown]
# # Integration by Parts and Structured Decomposition
#
# This notebook demonstrates product-rule decomposition, boundary terms, residual integrals, direct-versus-decomposed residuals, unit checks, and structured interpretation.

# %% [markdown]
# $$\int_a^b u(x)v'(x)\,dx = u(b)v(b)-u(a)v(a)-\int_a^b v(x)u'(x)\,dx$$
