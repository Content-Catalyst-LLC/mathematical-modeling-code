# %% [markdown]
# # Mechanistic Explanation and the Limits of Formalism
#
# Notebook placeholder for mechanism records, formal representation records, parameter interpretation, causal-claim boundaries, explanatory scope, black-box risk, and model governance.

# %% [markdown]
# $$\frac{dx}{dt}=f(x,t,\theta)$$
# $$\text{Formal precision}\neq\text{explanatory validity}$$
