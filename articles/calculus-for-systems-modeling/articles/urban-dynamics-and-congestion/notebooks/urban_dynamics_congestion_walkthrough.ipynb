# %% [markdown]
# # Urban Dynamics and Congestion
#
# Urban stocks, flows, density-speed-flow relationships, bottlenecks, queues, travel time, induced demand, accessibility, and governance.

# %% [markdown]
# $$\frac{dN}{dt}=q_{in}(t)-q_{out}(t)$$
# $$q=kv$$
# $$\frac{dQ}{dt}=a(t)-s(t)$$
# $$T=T_0\left(1+\alpha\left(\frac{V}{C}\right)^\beta\right)$$
