# %% [markdown]
# # Phase Lines, Phase Planes, and Phase Portraits
#
# Placeholder for phase lines, phase planes, vector fields, trajectories, nullclines, equilibria, basins of attraction, numerical simulation, and model governance.

# %% [markdown]
# $$x'=f(x)$$
# $$\mathbf{x}'=\mathbf{F}(\mathbf{x})$$
