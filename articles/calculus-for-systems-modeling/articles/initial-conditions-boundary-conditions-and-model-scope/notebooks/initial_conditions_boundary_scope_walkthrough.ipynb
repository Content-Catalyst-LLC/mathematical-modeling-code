# %% [markdown]
# # Initial Conditions, Boundary Conditions, and Model Scope
#
# Notebook placeholder for initial values, boundary types, temporal scope, spatial domains, parameter ranges, sensitivity to starting assumptions, and claim boundaries.

# %% [markdown]
# $$\frac{dx}{dt}=f(x,t,\theta), \qquad x(t_0)=x_0$$
# $$t\in[0,T],\quad x\in\Omega,\quad \theta\in\Theta$$
