# %% [markdown]
# # When Continuous Models Mislead
#
# Notebook placeholder for continuity assumptions, false smoothness, hidden thresholds, equilibrium bias, aggregation risk, solver diagnostics, domain drift, and claim boundaries.

# %% [markdown]
# $$\frac{dx}{dt}=f(x,t,\theta)$$
# $$x(t)\ \text{smooth}\quad\not\Rightarrow\quad\text{system behavior is smooth}$$
