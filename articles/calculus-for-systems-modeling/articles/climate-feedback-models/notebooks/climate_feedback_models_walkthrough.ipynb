# %% [markdown]
# # Case Study: Climate Feedback Models
#
# Energy balance, radiative forcing, feedback strength, ocean heat uptake, carbon-cycle feedback, sensitivity, and claim boundaries.

# %% [markdown]
# $$C\frac{dT}{dt}=F-\lambda T$$
# $$T^*=\frac{F}{\lambda}$$
# $$F_{CO_2}\approx 5.35\ln\left(\frac{C}{C_0}\right)$$
