# %% [markdown]
# # Second-Order Equations and Oscillatory Systems
#
# Placeholder for acceleration, damping, forcing, resonance, phase-space transformation, numerical simulation, and model governance.

# %% [markdown]
# $$x''+2\zeta\omega_0x'+\omega_0^2x=F(t)$$
