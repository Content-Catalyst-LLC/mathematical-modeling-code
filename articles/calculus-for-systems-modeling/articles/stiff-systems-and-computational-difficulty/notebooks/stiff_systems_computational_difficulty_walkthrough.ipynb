# %% [markdown]
# # Stiff Systems and Computational Difficulty
#
# Placeholder for time-scale separation, explicit and implicit method comparisons, amplification-factor checks, solver diagnostics, scaling review, and stiffness governance.

# %% [markdown]
# $$y'=\lambda y$$
# $$y_{n+1}=(1+h\lambda)y_n$$
# $$|1+h\lambda|\leq1$$
