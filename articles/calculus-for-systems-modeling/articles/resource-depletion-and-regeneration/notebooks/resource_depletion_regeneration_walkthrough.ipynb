# %% [markdown]
# # Resource Depletion and Regeneration
#
# Stocks, flows, extraction, regeneration, carrying capacity, thresholds, sustainable yield, and governance.

# %% [markdown]
# $$\frac{dR}{dt}=G(R,t)-H(R,t)-L(R,t)$$
# $$\frac{dR}{dt}=rR\left(1-\frac{R}{K}\right)-H$$
# $$MSY=\frac{rK}{4}$$
