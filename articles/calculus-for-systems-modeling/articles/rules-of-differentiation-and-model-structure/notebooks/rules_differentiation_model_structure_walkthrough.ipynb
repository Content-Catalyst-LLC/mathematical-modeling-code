# %% [markdown]
# # Rules of Differentiation and Model Structure
#
# This notebook demonstrates structural derivative audits for sum, product, quotient, and chain-rule model structures.

# %% [markdown]
# $$D(fg)=fDg+gDf$$
#
# The product rule reveals interaction structure.
