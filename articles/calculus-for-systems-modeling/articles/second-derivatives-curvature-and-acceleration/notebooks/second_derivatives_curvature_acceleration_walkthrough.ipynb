# %% [markdown]
# # Second Derivatives, Curvature, and Acceleration
#
# This notebook demonstrates second-derivative audits, curvature diagnostics, concavity classification, inflection-candidate review, and finite-difference checks.

# %% [markdown]
# $$f''(x) \approx \frac{f(x+h)-2f(x)+f(x-h)}{h^2}$$
