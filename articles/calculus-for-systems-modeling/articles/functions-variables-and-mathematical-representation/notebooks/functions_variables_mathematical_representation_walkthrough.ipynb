# %% [markdown]
# # Functions, Variables, and Mathematical Representation\n\nThis notebook compares functional forms and shows why representation choices shape system behavior.

# %% [markdown]
# $$y=f(x;\\theta)$$\n\nVariables, parameters, and functional forms should be explicit and reviewable.

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom functions_variables_mathematical_representation.core import evaluate_models, summarize_results\nrows = evaluate_models([i * 0.5 for i in range(21)])\nsummarize_results(rows)
