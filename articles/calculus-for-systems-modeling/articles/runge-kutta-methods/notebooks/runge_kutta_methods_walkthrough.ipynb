# %% [markdown]
# # Runge–Kutta Methods
#
# Placeholder for midpoint methods, RK2, RK4, stage diagnostics, Euler-versus-RK4 comparison, step-size sensitivity, local error, global error, stability, stiffness warnings, and model governance.

# %% [markdown]
# $$k_1=f(t_n,y_n)$$
# $$k_2=f\left(t_n+\frac{h}{2},y_n+\frac{h}{2}k_1\right)$$
# $$k_3=f\left(t_n+\frac{h}{2},y_n+\frac{h}{2}k_2\right)$$
# $$k_4=f(t_n+h,y_n+hk_3)$$
# $$y_{n+1}=y_n+\frac{h}{6}(k_1+2k_2+2k_3+k_4)$$
