# %% [markdown]
# # Diffusion, Transport, and Spatial Dynamics
#
# Placeholder for state fields, diffusion, transport, advection-diffusion, gradients, flux, source-sink terms, boundary conditions, conservation reasoning, numerical grids, stability ratios, and model governance.

# %% [markdown]
# $$\frac{\partial u}{\partial t}=D\nabla^2u$$
# $$\frac{\partial u}{\partial t}+v\frac{\partial u}{\partial x}=D\frac{\partial^2u}{\partial x^2}$$
# $$\frac{\partial u}{\partial t}+\nabla\cdot J=S-R$$
