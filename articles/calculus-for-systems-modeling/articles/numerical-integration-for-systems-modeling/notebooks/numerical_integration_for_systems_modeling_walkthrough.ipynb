# %% [markdown]
# # Numerical Integration for Systems Modeling\n\nRiemann sums, trapezoidal approximation, cumulative totals, exposure burden, spatial integration, conservation checks, step-size sensitivity, and governance.

# %% [markdown]
# $$\\int_a^b f(t)\\,dt \\approx \\sum_i f(t_i)\\Delta t$$\n$$\\int_a^b f(t)\\,dt \\approx \\sum_i \\frac{f(t_i)+f(t_{i+1})}{2}\\Delta t$$\n
