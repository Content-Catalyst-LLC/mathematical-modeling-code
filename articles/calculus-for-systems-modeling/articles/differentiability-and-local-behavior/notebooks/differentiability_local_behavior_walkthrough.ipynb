# %% [markdown]
# # Differentiability and Local Behavior\n\nThis notebook demonstrates local linearization error, one-sided finite differences, and kink diagnostics.

# %% [markdown]
# $$f(a+h)=f(a)+f'(a)h+o(h)$$\n\nDifferentiability means a first-order linear approximation captures local behavior up to a smaller-order remainder.

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom differentiability_local_behavior.core import finite_difference_diagnostics, kink_response\nfinite_difference_diagnostics('kink_abs_response', kink_response, 0.0, [1.0, 0.5, 0.25])
