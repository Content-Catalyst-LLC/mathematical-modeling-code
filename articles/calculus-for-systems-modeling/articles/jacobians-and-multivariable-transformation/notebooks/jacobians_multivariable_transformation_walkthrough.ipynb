# %% [markdown]
# # Jacobians and Multivariable Transformation
#
# Placeholder for Jacobian matrices, local linear maps, determinant scaling, singularity diagnostics, and transformation audits.

# %% [markdown]
# $$d\mathbf{y}\approx J_{\mathbf{F}}(\mathbf{x})d\mathbf{x}$$
