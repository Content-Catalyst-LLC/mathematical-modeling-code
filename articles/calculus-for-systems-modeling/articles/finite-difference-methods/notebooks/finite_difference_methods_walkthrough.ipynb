# %% [markdown]
# # Finite Difference Methods\n\nGrids, time steps, differences, stencils, explicit updates, boundary conditions, diffusion schemes, stability, convergence, and artifact review.

# %% [markdown]
# $$f'(x_i)\\approx \\frac{f_{i+1}-f_{i-1}}{2\\Delta x}$$\n$$f''(x_i)\\approx \\frac{f_{i+1}-2f_i+f_{i-1}}{(\\Delta x)^2}$$\n$$u_i^{n+1}=u_i^n+\\lambda(u_{i+1}^n-2u_i^n+u_{i-1}^n)$$\n
