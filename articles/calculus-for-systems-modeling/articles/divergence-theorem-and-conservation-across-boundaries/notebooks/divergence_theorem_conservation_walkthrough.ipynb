# %% [markdown]
# # The Divergence Theorem and Conservation Across Boundaries
#
# Placeholder for closed surfaces, outward normals, boundary flux, interior divergence, conservation across boundaries, and theorem governance.

# %% [markdown]
# $$\iint_{\partial V}\mathbf{F}\cdot\mathbf{n}\,dS=\iiint_V\nabla\cdot\mathbf{F}\,dV$$
