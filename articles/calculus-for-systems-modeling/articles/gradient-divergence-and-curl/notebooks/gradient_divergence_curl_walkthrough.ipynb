# %% [markdown]
# # Gradient, Divergence, and Curl
#
# Placeholder for scalar fields, vector fields, gradient, divergence, curl, finite differences, grid resolution, and derivative governance.

# %% [markdown]
# $$\nabla f \qquad \nabla\cdot\mathbf{F} \qquad \nabla\times\mathbf{F}$$
