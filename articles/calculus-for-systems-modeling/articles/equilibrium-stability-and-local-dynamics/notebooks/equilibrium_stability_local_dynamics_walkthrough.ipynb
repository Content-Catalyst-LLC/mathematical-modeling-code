# %% [markdown]
# # Equilibrium, Stability, and Local Dynamics
#
# Placeholder for equilibrium candidates, perturbations, local stability, phase-line interpretation, local linearization, Jacobians, basins of attraction, numerical simulation, and model governance.

# %% [markdown]
# $$f(x^*)=0$$
# $$f'(x^*)<0 \Rightarrow \text{locally stable}$$
