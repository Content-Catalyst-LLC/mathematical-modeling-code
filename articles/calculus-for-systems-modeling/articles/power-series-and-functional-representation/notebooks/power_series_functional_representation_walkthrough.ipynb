# %% [markdown]
# # Power Series and Functional Representation
#
# This notebook is a placeholder for a convergence-aware power-series walkthrough.

# %% [markdown]
# $$\sum_{n=0}^{\infty}c_n(x-a)^n$$
