# %% [markdown]
# # Stokes' Theorem and Rotational Structure
#
# Placeholder for oriented surfaces, boundary curves, curl flux, right-hand-rule orientation, boundary circulation, and theorem governance.

# %% [markdown]
# $$\oint_{\partial S}\mathbf{F}\cdot d\mathbf{r}=\iint_S(\nabla\times\mathbf{F})\cdot\mathbf{n}\,dS$$
