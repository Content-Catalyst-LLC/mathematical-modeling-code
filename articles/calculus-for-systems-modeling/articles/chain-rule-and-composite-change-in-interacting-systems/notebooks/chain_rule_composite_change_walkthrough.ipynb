# %% [markdown]
# # The Chain Rule and Composite Change in Interacting Systems
#
# This notebook demonstrates chain-rule pathway decomposition, local sensitivities, and finite-difference checks.

# %% [markdown]
# $$\frac{d}{dx}f(g(x))=f'(g(x))g'(x)$$
