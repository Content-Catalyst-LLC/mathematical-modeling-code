# %% [markdown]
# # Elasticity, Sensitivity, and Marginal Response
#
# This notebook demonstrates marginal response, elasticity, normalized sensitivity, finite-difference checks, and domain warnings.

# %% [markdown]
# $$E_f(x)=\frac{x f'(x)}{f(x)}$$
