# %% [markdown]
# # Advanced Population Dynamics
#
# Exponential, logistic, Allee effects, harvesting, stochasticity, structured populations, spatial migration, calibration, and identifiability.

# %% [markdown]
# $$\frac{dN}{dt}=rN$$
# $$\frac{dN}{dt}=rN\left(1-\frac{N}{K}\right)$$
# $$\frac{dN}{dt}=rN\left(1-\frac{N}{K}\right)\left(\frac{N}{A}-1\right)$$
# $$dN=rN\left(1-\frac{N}{K}\right)dt+\sigma N\,dW_t$$
