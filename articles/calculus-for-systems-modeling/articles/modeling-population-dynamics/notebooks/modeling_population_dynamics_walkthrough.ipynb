# %% [markdown]
# # Case Study: Modeling Population Dynamics
#
# Notebook placeholder for exponential growth, logistic growth, carrying capacity, equilibrium, sensitivity, calibration, and claim boundaries.

# %% [markdown]
# $$\frac{dN}{dt}=rN$$
# $$\frac{dN}{dt}=rN\left(1-\frac{N}{K}\right)$$
