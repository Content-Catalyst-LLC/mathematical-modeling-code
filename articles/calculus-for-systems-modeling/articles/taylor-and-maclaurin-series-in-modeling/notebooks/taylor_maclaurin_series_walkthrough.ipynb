# %% [markdown]
# # Taylor and Maclaurin Series in Modeling
#
# This notebook is a placeholder for derivative-based approximation, linearization, curvature, and truncation-error workflows.

# %% [markdown]
# $$f(x)=\sum_{n=0}^{\infty}\frac{f^{(n)}(a)}{n!}(x-a)^n$$
