# %% [markdown]
# # Substitution and Transformations of Accumulation
#
# This notebook demonstrates change of variables, transformed bounds, scale factors, unit checks, monotonicity review, and direct-versus-transformed accumulation residuals.

# %% [markdown]
# $$\int_a^b f(g(x))g'(x)\,dx = \int_{g(a)}^{g(b)} f(u)\,du$$
