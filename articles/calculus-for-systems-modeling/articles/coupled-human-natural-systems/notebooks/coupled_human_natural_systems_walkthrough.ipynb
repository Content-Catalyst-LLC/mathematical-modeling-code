# %% [markdown]
# # Coupled Human-Natural Systems
#
# Human-natural feedback, extraction, regeneration, adaptation, governance, thresholds, resilience, and distributional burden.

# %% [markdown]
# $$\frac{dH}{dt}=f(H,N,I,G,t)$$
# $$\frac{dN}{dt}=g(N,H,E,R,t)$$
# $$\frac{dR}{dt}=rR\left(1-\frac{R}{K}\right)-E(H,R,t)$$
