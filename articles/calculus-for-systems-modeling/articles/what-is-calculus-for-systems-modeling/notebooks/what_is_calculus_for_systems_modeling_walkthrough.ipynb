# %% [markdown]
# # What Is Calculus for Systems Modeling?\n\nThis notebook connects derivatives, accumulation, and dynamic simulation to systems modeling interpretation.

# %% [markdown]
# $$\\frac{dS}{dt}=rS\\left(1-\\frac{S}{K}\\right)$$\n\nThis small model shows how a rate rule becomes a system trajectory.

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom what_is_calculus_for_systems_modeling.core import load_scenarios, simulate_logistic, summarize_runs\nrows = []\nfor scenario in load_scenarios(ARTICLE_ROOT / 'data' / 'system_scenarios.csv'):\n    rows.extend(simulate_logistic(scenario))\nsummarize_runs(rows)
