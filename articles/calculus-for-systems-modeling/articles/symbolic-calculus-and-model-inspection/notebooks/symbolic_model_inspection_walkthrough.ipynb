# %% [markdown]
# # Symbolic Calculus and Model Inspection
#
# Placeholder for symbolic differentiation, integration records, limits, equilibria, Jacobians, Hessians, domain assumptions, expression governance, and exact-to-numeric model review.

# %% [markdown]
# $$f(x)=rx\left(1-\frac{x}{K}\right)$$
# $$f'(x)=r-\frac{2rx}{K}$$
# $$f(x)=0\Rightarrow x=0\text{ or }x=K$$
