# %% [markdown]
# # Related Rates and Interdependent Motion
#
# This notebook demonstrates related-rates audits, interdependent motion diagnostics, finite-difference checks, and operating-point review.

# %% [markdown]
# $$\frac{dy}{dt}=\frac{dy}{dx}\frac{dx}{dt}$$
