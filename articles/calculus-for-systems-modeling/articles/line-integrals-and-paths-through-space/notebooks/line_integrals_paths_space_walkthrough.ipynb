# %% [markdown]
# # Line Integrals and Paths Through Space
#
# Placeholder for scalar line integrals, vector line integrals, path sampling, scalar accumulation, dot-product alignment, circulation, and path-dependence diagnostics.

# %% [markdown]
# $$\int_C f\,ds \qquad \int_C \mathbf{F}\cdot d\mathbf{r}$$
