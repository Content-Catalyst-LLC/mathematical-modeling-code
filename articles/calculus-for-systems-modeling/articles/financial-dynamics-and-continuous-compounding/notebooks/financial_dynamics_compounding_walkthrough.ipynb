# %% [markdown]
# # Financial Dynamics and Continuous Compounding
#
# Rates, value, time, compounding, discounting, debt, risk, cash flows, and governance.

# %% [markdown]
# $$\frac{dV}{dt}=rV$$
# $$V(t)=V_0e^{rt}$$
# $$PV=FVe^{-rt}$$
# $$PV=\int_0^T C(t)e^{-rt}\,dt$$
