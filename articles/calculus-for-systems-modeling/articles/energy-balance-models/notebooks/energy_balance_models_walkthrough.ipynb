# %% [markdown]
# # Energy Balance Models
#
# Energy stocks, flows, conservation, heat capacity, forcing, feedback, equilibrium, and thermal response.

# %% [markdown]
# $$\frac{dE}{dt}=F_{in}(t)-F_{out}(t)$$
# $$C\frac{dT}{dt}=F-\lambda T$$
# $$T^*=\frac{F}{\lambda}$$
# $$\tau=\frac{C}{\lambda}$$
