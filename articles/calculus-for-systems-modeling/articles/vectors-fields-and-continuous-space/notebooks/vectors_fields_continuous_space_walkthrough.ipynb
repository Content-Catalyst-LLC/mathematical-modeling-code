# %% [markdown]
# # Vectors, Fields, and Continuous Space
#
# Placeholder for vectors, scalar fields, vector fields, field magnitude diagnostics, grid resolution checks, and continuous-space interpretation.

# %% [markdown]
# $$\mathbf{F}(x,y)=\langle P(x,y),Q(x,y)\rangle$$
