# %% [markdown]
# # Sensitivity, Robustness, and Parameter Dependence
#
# Notebook placeholder for baseline parameters, local sensitivity, elasticity, finite differences, parameter sweeps, robustness classifications, threshold warnings, and claim boundaries.

# %% [markdown]
# $$S_i=\frac{\partial y}{\partial \theta_i}$$
# $$E_i=\frac{\theta_i}{y}\frac{\partial y}{\partial \theta_i}$$
