# %% [markdown]
# # Euler's Method
#
# Placeholder for explicit time stepping, slope-based updates, initial conditions, step-size sensitivity, local error, global error, stability, exponential decay benchmarks, logistic growth examples, and model governance.

# %% [markdown]
# $$y_{n+1}=y_n+h f(t_n,y_n)$$
# $$\frac{dy}{dt}=-ky$$
# $$y_{n+1}=(1-hk)y_n$$
