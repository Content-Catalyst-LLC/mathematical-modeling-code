# %% [markdown]
# # Convergence Tests and the Discipline of Infinite Approximation
#
# This notebook demonstrates term-test screening, geometric and p-series classification, comparison logic, alternating-series error bounds, stopping-rule review, and finite-versus-infinite interpretation.

# %% [markdown]
# $$0\leq a_n\leq b_n,\quad \sum b_n\text{ converges}\Rightarrow \sum a_n\text{ converges}$$
