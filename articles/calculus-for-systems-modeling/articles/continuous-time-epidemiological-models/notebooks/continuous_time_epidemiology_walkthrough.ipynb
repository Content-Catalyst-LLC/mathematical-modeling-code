# %% [markdown]
# # Continuous-Time Epidemiological Models
#
# SIR and SEIR systems, force of infection, reproduction numbers, vaccination, reporting assumptions, and governance.

# %% [markdown]
# $$\frac{dS}{dt}=-\beta\frac{SI}{N}$$
# $$\frac{dI}{dt}=\beta\frac{SI}{N}-\gamma I$$
# $$R_0=\frac{\beta}{\gamma}$$
# $$R_t=R_0\frac{S(t)}{N(t)}$$
