# %% [markdown]
# # Infinity, Infinitesimals, and the Historical Problem of Change\n\nThis notebook demonstrates difference quotients, refinement, and convergence for a smooth synthetic system-response function.

# %% [markdown]
# $$f'(x)=\\lim_{h\\to 0}\\frac{f(x+h)-f(x)}{h}$$\n\nThe derivative connects average change over finite intervals to local change under refinement.

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom infinity_infinitesimals_change.core import run_approximations, summarize_approximations\nrecords = run_approximations(5.0, [1.0, 0.5, 0.1, 0.01, 0.001])\nsummarize_approximations(records)
