# %% [markdown]
# # Case Study: Carbon Accumulation and Emissions Pathways
#
# Stocks, flows, cumulative emissions, atmospheric burden, carbon budgets, net zero, overshoot, and governance.

# %% [markdown]
# $$\frac{dC_A}{dt}=E(t)-S_L(t)-S_O(t)$$
# $$E_{cum}(T)=\int_0^T E(t)\,dt$$
# $$C_A(t)=C_A(0)+\int_0^t E(\tau)R(t-\tau)\,d\tau$$
