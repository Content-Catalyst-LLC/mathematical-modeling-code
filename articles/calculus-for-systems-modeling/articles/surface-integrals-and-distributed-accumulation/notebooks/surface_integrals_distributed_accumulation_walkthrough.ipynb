# %% [markdown]
# # Surface Integrals and Distributed Accumulation
#
# Placeholder for scalar surface integrals, vector flux integrals, surface area, normal vectors, patch sampling, mesh resolution, and boundary interpretation.

# %% [markdown]
# $$\iint_S f\,dS \qquad \iint_S \mathbf{F}\cdot d\mathbf{S}$$
