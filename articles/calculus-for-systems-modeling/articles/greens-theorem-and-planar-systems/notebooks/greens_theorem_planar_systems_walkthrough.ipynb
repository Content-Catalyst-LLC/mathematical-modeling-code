# %% [markdown]
# # Green's Theorem and Planar Systems
#
# Placeholder for planar vector fields, closed curves, circulation form, flux form, curl/divergence comparison, and boundary-region governance.

# %% [markdown]
# $$\oint_C P\,dx+Q\,dy = \iint_R \left(\frac{\partial Q}{\partial x}-\frac{\partial P}{\partial y}\right)dA$$
