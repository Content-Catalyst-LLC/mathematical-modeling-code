# %% [markdown]
# # Antiderivatives and the Recovery of Accumulation
#
# This notebook demonstrates antiderivative recovery, flow-to-stock reconstruction, initial-condition selection, unit checks, and numerical accumulation.

# %% [markdown]
# $$Q(t)=Q_0+\int_{t_0}^{t}r(s)\,ds$$
