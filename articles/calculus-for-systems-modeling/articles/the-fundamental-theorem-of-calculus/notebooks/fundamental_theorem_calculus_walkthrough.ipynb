# %% [markdown]
# # The Fundamental Theorem of Calculus
#
# This notebook demonstrates accumulation functions, endpoint differences, rate-state reconciliation, residual diagnostics, and unit checks.

# %% [markdown]
# $$Q(b)-Q(a)=\int_a^b r(t)\,dt$$
