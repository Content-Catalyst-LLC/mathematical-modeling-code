# %% [markdown]
# # Domains, Ranges, and the Structure of Functional Models
#
# This notebook demonstrates domain checks, range checks, and validation-before-interpretation for a synthetic bounded-growth model.

# %% [markdown]
# $$f:X\to Y$$
#
# In systems modeling, the domain is a model boundary and the range is an interpretable output space.

# %%
from pathlib import Path
import sys
ARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ARTICLE_ROOT / 'python'))
from domains_ranges_functional_models.core import load_scenarios, evaluate_scenarios
scenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'domain_range_scenarios.csv')
evaluate_scenarios(scenarios)
