# %% [markdown]
# # Economic Growth and Adjustment Models
#
# Output, growth rates, capital accumulation, productivity, adjustment, shocks, constraints, and governance.

# %% [markdown]
# $$\frac{dY}{dt}=gY$$
# $$Y(t)=Y_0e^{gt}$$
# $$\frac{dK}{dt}=I(t)-\delta K(t)$$
# $$Y=AK^\alpha L^{1-\alpha}$$
