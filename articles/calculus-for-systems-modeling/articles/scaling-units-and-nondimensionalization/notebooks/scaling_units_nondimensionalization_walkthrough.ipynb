# %% [markdown]
# # Scaling, Units, and Nondimensionalization
#
# Notebook placeholder for unit records, reference scales, nondimensional variables, dimensionless groups, conversion checks, and model governance.

# %% [markdown]
# $$x^*=\frac{x}{X},\qquad t^*=\frac{t}{T}$$
# $$\frac{dx}{dt}=rx\left(1-\frac{x}{K}\right),\qquad \frac{du}{d\tau}=u(1-u)$$
