# %% [markdown]
# # Introduction to Partial Differential Equations
#
# Placeholder for state fields, partial derivatives, domains, boundary conditions, initial conditions, diffusion, transport, waves, finite-difference grids, stability ratios, and model governance.

# %% [markdown]
# $$u=u(x,t)$$
# $$\frac{\partial u}{\partial t}=D\frac{\partial^2 u}{\partial x^2}$$
# $$u_i^{n+1}=u_i^n+\lambda(u_{i+1}^n-2u_i^n+u_{i-1}^n)$$
