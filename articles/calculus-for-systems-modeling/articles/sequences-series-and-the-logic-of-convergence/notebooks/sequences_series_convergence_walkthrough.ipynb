# %% [markdown]
# # Sequences, Series, and the Logic of Convergence
#
# This notebook demonstrates sequence limits, partial sums, geometric series, harmonic divergence, p-series classification, stopping rules, and remainder interpretation.

# %% [markdown]
# $$S_N=\sum_{n=1}^{N}a_n,\qquad \sum_{n=1}^{\infty}a_n=S\text{ if }\lim_{N\to\infty}S_N=S$$
