# %% [markdown]
# # Constrained Optimization and Lagrange Multipliers
#
# Placeholder for feasible regions, Lagrange multiplier diagnostics, stationarity residuals, shadow values, and active-constraint review.

# %% [markdown]
# $$\nabla f(\mathbf{x}^*)=\lambda \nabla g(\mathbf{x}^*)$$
