# %% [markdown]
# # Flux, Circulation, and Spatial Flow
#
# Placeholder for vector fields, flux, circulation, orientation, sampling, divergence/curl connections, and spatial-flow governance.

# %% [markdown]
# $$\iint_S \mathbf{F}\cdot\mathbf{n}\,dS \qquad \oint_C \mathbf{F}\cdot d\mathbf{r}$$
