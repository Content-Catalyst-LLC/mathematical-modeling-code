# %% [markdown]
# # Definite Integrals and Total Change
#
# This notebook demonstrates signed accumulation, absolute accumulation, interval records, unit checks, and numerical total-change estimation.

# %% [markdown]
# $$Q(b)-Q(a)=\int_a^b r(t)\,dt$$
