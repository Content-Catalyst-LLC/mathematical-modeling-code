# %% [markdown]
# # Limits and the Formal Basis of Calculus\n\nThis notebook demonstrates convergence-order review for forward difference, central difference, and Richardson extrapolation.

# %% [markdown]
# $$\\lim_{x\\to a} f(x)=L$$\n\n$$\\forall \\varepsilon>0,\\exists \\delta>0:0<|x-a|<\\delta\\Rightarrow |f(x)-L|<\\varepsilon$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom limits_formal_basis.core import convergence_study, convergence_orders\nrows = convergence_study(5.0, [1.0, 0.5, 0.25, 0.125])\nconvergence_orders(rows)
