# %% [markdown]
# # Robustness, Fragility, and Model Dependence\n\nThis notebook demonstrates how robustness matrices, fragility classes, threshold disagreement, and dependence registers can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$C=g(D,\\theta,A,m,r)$$\n\n$$d^*=\\arg\\max_d\\min_{\\omega\\in\\Omega}U(d,\\omega)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom robustness_fragility_and_model_dependence.core import load_scenarios, robustness_rows, robustness_summary\nitems = load_scenarios(ARTICLE_ROOT / 'data' / 'robustness_scenarios.csv')\nrows = robustness_rows(items)\nrobustness_summary(rows)
