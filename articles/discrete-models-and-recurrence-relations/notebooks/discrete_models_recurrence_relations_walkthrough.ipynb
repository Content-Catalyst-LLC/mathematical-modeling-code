# %% [markdown]
# # Discrete Models and Recurrence Relations\n\nThis notebook demonstrates how recurrence records, stepwise updates, boundary events, adaptive demand, and trajectory summaries can be treated as reviewable model objects.

# %% [markdown]
# $$S_{t+1}=\\min(K,\\max(0,S_t+I_t-D_t-\\lambda S_t))$$\n\n$$D_{t+1}=\\max(0,D_t-\\alpha Q_t)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom discrete_models_recurrence_relations.core import load_recurrence_scenarios, simulate_recurrence, summarize_trajectory\nscenarios = load_recurrence_scenarios(ARTICLE_ROOT / 'data' / 'recurrence_scenarios.csv')\nrows = simulate_recurrence(scenarios[0])\nsummarize_trajectory(rows)
