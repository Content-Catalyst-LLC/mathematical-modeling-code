# %% [markdown]
# # Scientific Computing for Modeling Workflows\n\nThis notebook demonstrates how workflow registers, run manifests, output hashes, and reproducibility diagnostics can be treated as model governance artifacts.

# %% [markdown]
# $$Y = W(D,\\theta,C,E)$$\n\n$$W(D,\\theta,C,E) \\longrightarrow (Y,Q,M)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom scientific_computing_modeling_workflows.core import load_scenarios, simulate, summarize_trajectories\nrows = []\nfor scenario in load_scenarios(ARTICLE_ROOT / 'data' / 'resource_workflow_scenarios.csv'):\n    rows.extend(simulate(scenario))\nsummarize_trajectories(rows)
