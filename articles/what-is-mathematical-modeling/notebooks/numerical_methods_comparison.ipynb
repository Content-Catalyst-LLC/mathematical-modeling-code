# %% [markdown]
# # Numerical Methods Comparison\n\nThis notebook compares Euler and RK4 integration for the same mathematical model.

# %%
from pathlib import Path\nimport sys\n\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\n\nfrom what_is_mathematical_modeling.core import LogisticModel, simulate_euler, simulate_rk4\n\nmodel = LogisticModel('method_compare', 10.0, 0.35, 100.0, 0.1, 160)\neuler = simulate_euler(model)\nrk4 = simulate_rk4(model)\n{'euler_final': euler.final_state, 'rk4_final': rk4.final_state, 'difference': rk4.final_state - euler.final_state}
