# %% [markdown]
# # What Is Mathematical Modeling?\n\nThis notebook demonstrates the modeling cycle: purpose, variables, parameters, assumptions, equations, simulation, diagnostics, uncertainty, and interpretation.

# %% [markdown]
# $$\\frac{dx}{dt}=rx\\left(1-\\frac{x}{K}\\right)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom what_is_mathematical_modeling.core import load_scenarios, simulate_rk4, sensitivity_oat\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'scenario_definitions.csv')\nresult = simulate_rk4(scenarios[0])\nresult.rows[:3], result.rows[-1], sensitivity_oat(scenarios[0])
