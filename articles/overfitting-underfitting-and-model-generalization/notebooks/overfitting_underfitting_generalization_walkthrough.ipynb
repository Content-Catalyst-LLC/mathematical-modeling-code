# %% [markdown]
# # Overfitting, Underfitting, and Model Generalization\n\nThis notebook demonstrates how training error, validation error, overfit gaps, underfit warnings, complexity, interpretability, and decision-use cautions can be treated as reproducible generalization artifacts.

# %% [markdown]
# $$E_{\\text{gen}}(M)=\\mathbb{E}_{(x,y)\\sim P_{\\text{use}}}[L(y,M(x))]$$\n\n$$\\hat{M}=\\arg\\min_{M\\in\\mathcal{M}}[E_{\\text{train}}(M)+\\lambda C(M)]$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom overfitting_underfitting_generalization.core import load_models, model_rows\nmodels = load_models(ARTICLE_ROOT / 'data' / 'generalization_models.csv')\nmodel_rows(models)
