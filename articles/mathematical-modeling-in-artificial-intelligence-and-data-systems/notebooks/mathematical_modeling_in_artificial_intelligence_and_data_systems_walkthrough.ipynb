# %% [markdown]
# # Mathematical Modeling in Artificial Intelligence and Data Systems\n\nThis notebook demonstrates how AI model registers, candidate governance reviews, calibration diagnostics, subgroup error gaps, drift scores, privacy risk, and deployment review cards can be treated as reproducible AI modeling artifacts.

# %% [markdown]
# $$\\hat{y}=f_\\theta(x)$$\n\n$$\\theta^*=\\arg\\min_{\\theta}\\frac{1}{n}\\sum_{i=1}^{n}L(f_\\theta(x_i),y_i)$$\n\n$$\\Delta_t=d(P_{\\text{train}}(X),P_t(X))$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_artificial_intelligence_and_data_systems.core import load_model_candidates, evaluate_candidate, deployment_summary\ncandidates = load_model_candidates(ARTICLE_ROOT / 'data' / 'model_candidates.csv')\nrows = [evaluate_candidate(candidate) for candidate in candidates]\ndeployment_summary(rows)
