# %% [markdown]
# # Mathematical Modeling in Science\n\nThis notebook demonstrates how scientific model registers, population-growth simulation, scenario summaries, and evidence cards can be treated as reproducible scientific modeling artifacts.

# %% [markdown]
# $$Y=f(X,\\theta,A,C)$$\n\n$$\\frac{dN}{dt}=rN\\left(1-\\frac{N}{K}\\right)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_science.core import load_population_scenarios, scenario_summary, evidence_summary\nscenarios = load_population_scenarios(ARTICLE_ROOT / 'data' / 'population_scenarios.csv')\nrows = [scenario_summary(scenario) for scenario in scenarios]\nevidence_summary(rows)
