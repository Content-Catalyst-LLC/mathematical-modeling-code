# %% [markdown]
# # Numerical Methods for Mathematical Models\n\nThis notebook demonstrates how step size, Euler approximation, convergence diagnostics, and numerical method records can be treated as reviewable model objects.

# %% [markdown]
# $$R_{t+h}=R_t+h\\left[gR_t\\left(1-\\frac{R_t}{K}\\right)-E\\right]$$\n\n$$\\lim_{h\\to 0} \\hat{Y}_h = Y$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom numerical_methods_for_mathematical_models.core import load_scenarios, run_euler, convergence_summary\nrows = []\nfor scenario in load_scenarios(ARTICLE_ROOT / 'data' / 'solver_scenarios.csv'):\n    rows.extend(run_euler(scenario))\nconvergence_summary(rows)
