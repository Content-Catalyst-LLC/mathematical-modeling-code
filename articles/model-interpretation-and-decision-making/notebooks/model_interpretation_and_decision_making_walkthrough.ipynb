# %% [markdown]
# # Model Interpretation and Decision-Making\n\nThis notebook demonstrates how interpretation registers, decision-option review, threshold risk, tradeoff documentation, and use limits can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$Y=f(D,\\theta,A,m,s)$$\n\n$$d=\\delta(Y,U,V,C)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom model_interpretation_and_decision_making.core import load_decision_options, evaluate_option, decision_summary\noptions = load_decision_options(ARTICLE_ROOT / 'data' / 'decision_options.csv')\nrows = [evaluate_option(option) for option in options]\ndecision_summary(rows)
