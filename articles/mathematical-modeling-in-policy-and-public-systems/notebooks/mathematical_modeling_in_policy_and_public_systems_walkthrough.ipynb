# %% [markdown]
# # Mathematical Modeling in Policy and Public Systems\n\nThis notebook demonstrates how policy model registers, option reviews, budget/equity/risk diagnostics, and public decision-support cards can be treated as reproducible policy modeling artifacts.

# %% [markdown]
# $$Y=f(p,X,C,A,U)$$\n\n$$p^*=\\arg\\max_{p\\in\\mathcal{P}} W(Y_p)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_policy_and_public_systems.core import load_policy_options, evaluate_policy_option, policy_summary\noptions = load_policy_options(ARTICLE_ROOT / 'data' / 'policy_options.csv')\nrows = [evaluate_policy_option(option) for option in options]\npolicy_summary(rows)
