# %% [markdown]
# # Model Purpose: Explanation, Prediction, Control, and Decision Support\n\nThis notebook demonstrates how model purpose can be represented as a reviewable design constraint.

# %% [markdown]
# $$U^*=\\{u\\in U:\\text{assumptions, validation, uncertainty, and evidence support }u\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom model_purpose.core import load_scenarios, simulate_resource, summarize_resource\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'purpose_scenarios.csv')\nrows = simulate_resource(scenarios[0])\nsummarize_resource(rows)
