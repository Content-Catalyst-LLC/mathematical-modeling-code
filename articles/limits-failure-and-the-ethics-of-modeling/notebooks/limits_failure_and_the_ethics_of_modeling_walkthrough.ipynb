# %% [markdown]
# # Limits, Failure, and the Ethics of Modeling\n\nThis notebook demonstrates how model failure registers, ethics risk scoring, governance queues, use-limit statements, and accountability review can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$\\hat{y}=f(x;\\theta,A)$$\n\n$$e_i=y_i-\\hat{y}_i$$\n\n$$x\\in\\mathcal{D}_{\\text{valid}}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom limits_failure_and_the_ethics_of_modeling.core import load_risk_cases, evaluate_risk_case, ethics_summary\ncases = load_risk_cases(ARTICLE_ROOT / 'data' / 'model_ethics_risk_cases.csv')\nrows = [evaluate_risk_case(case) for case in cases]\nethics_summary(rows)
