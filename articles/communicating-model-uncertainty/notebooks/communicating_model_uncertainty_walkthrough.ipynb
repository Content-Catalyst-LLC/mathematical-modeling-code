# %% [markdown]
# # Communicating Model Uncertainty\n\nThis notebook demonstrates how uncertainty communication cards, plain-language statements, audience guidance, and use limits can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$Y=f(D,\\theta,A,m,s)$$\n\n$$\\text{Claim}=h(Y,U,C,L)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom communicating_model_uncertainty.core import load_communication_records, load_uncertainty_messages, build_communication_card\nrecords = load_communication_records(ARTICLE_ROOT / 'data' / 'communication_records.csv')\nmessages = load_uncertainty_messages(ARTICLE_ROOT / 'data' / 'uncertainty_messages.csv')\ncard = build_communication_card(records, messages)\ncard['diagnostic_checks']
