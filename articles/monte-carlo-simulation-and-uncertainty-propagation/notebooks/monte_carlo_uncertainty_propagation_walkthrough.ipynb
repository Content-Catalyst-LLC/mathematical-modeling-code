# %% [markdown]
# # Monte Carlo Simulation and Uncertainty Propagation\n\nThis notebook demonstrates how input distributions, seeds, sampled ensembles, output quantiles, threshold probabilities, and convergence diagnostics can be treated as reviewable model objects.

# %% [markdown]
# $$Y^{(r)}=f(X^{(r)})$$\n\n$$\\widehat{P}(Y \\leq T)=\\frac{1}{R}\\sum_{r=1}^{R} I(Y^{(r)} \\leq T)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom monte_carlo_uncertainty_propagation.core import load_scenarios, run_monte_carlo, summarize\nscenario = load_scenarios(ARTICLE_ROOT / 'data' / 'monte_carlo_scenarios.csv')[0]\nrows = run_monte_carlo(scenario)\nsummarize(rows)
