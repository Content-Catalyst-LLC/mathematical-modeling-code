# %% [markdown]
# # Network Models and Graph Structures
#
# This notebook demonstrates how node definitions, edge lists, adjacency structures, reachability, centrality diagnostics, and network audit cards can be treated as reviewable model objects.

# %% [markdown]
# $$G=(V,E)$$
#
# $$A_{ij}=w_{ij}$$

# %%
from pathlib import Path
import sys
ARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ARTICLE_ROOT / 'python'))
from network_models_graph_structures.core import load_edges, degree_table, weak_component_count
edges = load_edges(ARTICLE_ROOT / 'data' / 'infrastructure_edges.csv')
degree_table(edges), weak_component_count(edges)
