# %% [markdown]
# # Mathematical Modeling in Engineering\n\nThis notebook demonstrates how engineering model registers, beam design review, stress margins, safety factors, and design review cards can be treated as reproducible engineering modeling artifacts.

# %% [markdown]
# $$Y=f(x,u,\\theta,A,C)$$\n\n$$M=R-S$$\n\n$$P_f=P(S>R)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_engineering.core import load_beam_designs, evaluate_beam, design_summary\ndesigns = load_beam_designs(ARTICLE_ROOT / 'data' / 'beam_designs.csv')\nrows = [evaluate_beam(design) for design in designs]\ndesign_summary(rows)
