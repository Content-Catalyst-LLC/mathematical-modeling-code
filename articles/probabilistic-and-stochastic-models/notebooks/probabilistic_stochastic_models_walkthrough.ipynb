# %% [markdown]
# # Probabilistic and Stochastic Models\n\nThis notebook demonstrates how probability model records, Monte Carlo simulation, risk summaries, and uncertainty diagnostics can be treated as reviewable model objects.

# %% [markdown]
# $$D\\sim\\mathrm{Lognormal}(\\mu,\\sigma)$$\n\n$$Q=\\max(0,D-S-\\mathrm{reserve})$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom probabilistic_stochastic_models.core import load_risk_scenarios, simulate_risk\nscenarios = load_risk_scenarios(ARTICLE_ROOT / 'data' / 'risk_scenarios.csv')\nrows, summary = simulate_risk(scenarios[0])\nsummary
