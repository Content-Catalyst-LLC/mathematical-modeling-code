# %% [markdown]
# # Mathematical Modeling in Public Health and Epidemiology\n\nThis notebook demonstrates how public health model registers, SIR intervention scenarios, hospital capacity review, surveillance/equity notes, and public health review cards can be treated as reproducible epidemiological modeling artifacts.

# %% [markdown]
# $$N=S(t)+I(t)+R(t)$$\n\n$$R_0=\\frac{\\beta}{\\gamma}$$\n\n$$P(H_t>C_t)\\leq \\alpha$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_public_health_and_epidemiology.core import load_epidemic_scenarios, evaluate_scenario, epidemic_summary\nscenarios = load_epidemic_scenarios(ARTICLE_ROOT / 'data' / 'epidemic_scenarios.csv')\nrows = [evaluate_scenario(scenario) for scenario in scenarios]\nepidemic_summary(rows)
