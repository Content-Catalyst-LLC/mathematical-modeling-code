# %% [markdown]
# # Model Governance and Accountability\n\nThis notebook demonstrates how governance registers, validation status, use limits, monitoring status, model ownership, decision ownership, and governance-risk scores can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$\\text{Use}(M,d)=1 \\quad \\text{only if} \\quad V(M)=1,\\; A(M,d)=1,\\; G(M,d)=1$$\n\n$$R(M)=f(E_M,U_M,C_D,S_M)$$\n\n$$R(M) \\geq \\tau \\Rightarrow \\text{escalate review}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom model_governance_and_accountability.core import load_governance_risk_cases, evaluate_governance_risk, governance_summary\ncases = load_governance_risk_cases(ARTICLE_ROOT / 'data' / 'model_governance_risk_cases.csv')\nrows = [evaluate_governance_risk(case) for case in cases]\ngovernance_summary(rows)
