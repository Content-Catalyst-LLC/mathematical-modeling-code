# %% [markdown]
# # Differential Equations and Dynamic Models\n\nThis notebook demonstrates how dynamic model records, rate equations, Euler integration, and trajectory summaries can be treated as reviewable model objects.

# %% [markdown]
# $$\\frac{dS}{dt}=I-D-\\lambda S$$\n\n$$S_{t+\\Delta t}\\approx S_t+\\Delta t(I-D-\\lambda S_t)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom differential_equations_dynamic_models.core import load_dynamic_scenarios, simulate_euler, summarize_trajectory\nscenarios = load_dynamic_scenarios(ARTICLE_ROOT / 'data' / 'dynamic_scenarios.csv')\nrows = simulate_euler(scenarios[0])\nsummarize_trajectory(rows)
