# %% [markdown]
# # Mathematical Modeling in Ecology and Sustainability\n\nThis notebook demonstrates how ecology model registers, renewable resource scenarios, resilience margins, threshold diagnostics, and sustainability review cards can be treated as reproducible ecological modeling artifacts.

# %% [markdown]
# $$S_{t+1}=S_t+G(S_t)-E_t$$\n\n$$M_t=S_t-S_{\\min}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom mathematical_modeling_in_ecology_and_sustainability.core import load_resource_scenarios, evaluate_scenario, sustainability_summary\nscenarios = load_resource_scenarios(ARTICLE_ROOT / 'data' / 'resource_scenarios.csv')\nrows = [evaluate_scenario(scenario) for scenario in scenarios]\nsustainability_summary(rows)
