# %% [markdown]
# # Algebraic Models and Static Relationships\n\nThis notebook demonstrates how algebraic relationships, constraints, and static scenario comparisons can be treated as reviewable model objects.

# %% [markdown]
# $$y=f(x;\\theta)$$\n\n$$F=\\{x:g_i(x)\\leq0,\\ h_j(x)=0\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom algebraic_models_static_relationships.core import load_scenarios, evaluate_scenario\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'static_allocation_scenarios.csv')\nevaluate_scenario(scenarios[0])
