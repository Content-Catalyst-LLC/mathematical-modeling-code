# %% [markdown]
# # Model Comparison and Selection\n\nThis notebook demonstrates how candidate model scores, validation error, complexity penalties, overfit gaps, interpretability, robustness, and decision relevance can be treated as reproducible model-selection artifacts.

# %% [markdown]
# $$M^*=\\arg\\min_{M_j\\in\\mathcal{M}} C(M_j;D,P)$$\n\n$$C(M)=E_{\\text{val}}(M)+\\lambda K(M)+\\gamma R(M)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom model_comparison_and_selection.core import load_candidates, model_rows\nmodels = load_candidates(ARTICLE_ROOT / 'data' / 'model_candidates.csv')\nmodel_rows(models)
