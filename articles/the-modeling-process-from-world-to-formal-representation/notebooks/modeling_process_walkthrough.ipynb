# %% [markdown]
# # The Modeling Process\n\nThis notebook walks from a real-world reservoir question to a formal stock-flow model, scenario simulation, assumption review, and revision planning.

# %% [markdown]
# $$S_{t+1}=\\min(K,\\max(0,S_t+I_t-D_t-L_t))$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom modeling_process.core import load_scenarios, simulate_reservoir, summarize_scenario\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'scenario_definitions.csv')\nrows = simulate_reservoir(scenarios[0])\nsummarize_scenario(rows)
