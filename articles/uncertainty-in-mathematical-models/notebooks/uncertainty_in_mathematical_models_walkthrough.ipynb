# %% [markdown]
# # Uncertainty in Mathematical Models\n\nThis notebook demonstrates how uncertainty sources, uncertain parameters, propagation runs, threshold probability, and assessment cards can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$Y=f(X,\\Theta)$$\n\n$$P(Y \\lt T)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom uncertainty_in_mathematical_models.core import load_parameters, propagation_rows, output_summary\nparams = load_parameters(ARTICLE_ROOT / 'data' / 'uncertain_parameters.csv')\nrows = propagation_rows(params)\noutput_summary(rows)
