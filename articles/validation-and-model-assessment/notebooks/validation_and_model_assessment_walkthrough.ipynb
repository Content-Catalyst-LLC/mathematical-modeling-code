# %% [markdown]
# # Validation and Model Assessment\n\nThis notebook demonstrates how validation observations, residual diagnostics, scenario summaries, fitness-for-purpose labels, and assessment cards can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$A = V(M,D,U,P)$$\n\n$$RMSE=\\sqrt{\\frac{1}{n}\\sum_{i=1}^{n}(y_i-\\hat{y}_i)^2}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom validation_and_model_assessment.core import load_observations, error_rows, metric_summary, scenario_summary, classify_fitness\nobs = load_observations(ARTICLE_ROOT / 'data' / 'validation_observations.csv')\nerrors = error_rows(obs)\noverall = metric_summary(errors)\n(overall, classify_fitness(overall), scenario_summary(errors))
