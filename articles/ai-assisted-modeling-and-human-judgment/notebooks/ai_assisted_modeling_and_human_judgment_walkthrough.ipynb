# %% [markdown]
# # AI-Assisted Modeling and Human Judgment\n\nThis notebook demonstrates how AI assistance registers, human judgment review, automation-bias risk scoring, provenance requirements, escalation flags, use limits, and accountability owners can be treated as reproducible governance artifacts.

# %% [markdown]
# $$\\hat{y}=f_{\\theta}(D,A,H)$$\n\n$$C=\\alpha(D,A,P)$$\n\n$$R(C,E,U,G)\\in\\{\\text{approve},\\text{revise},\\text{reject},\\text{escalate}\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom ai_assisted_modeling_and_human_judgment.core import load_human_judgment_cases, evaluate_judgment_case, judgment_summary\ncases = load_human_judgment_cases(ARTICLE_ROOT / 'data' / 'human_judgment_cases.csv')\nrows = [evaluate_judgment_case(case) for case in cases]\njudgment_summary(rows)
