# %% [markdown]
# # Optimization Models and Objective Functions\n\nThis notebook demonstrates how decision variables, objectives, constraints, feasible alternatives, and optimization audit cards can be treated as reviewable model objects.

# %% [markdown]
# $$x^* \\in \\arg\\max_{x\\in\\mathcal{F}} f(x)$$\n\n$$\\sum_i c_i x_i \\leq B$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom optimization_models_objective_functions.core import load_programs, load_scenarios, enumerate_choices, best_feasible\nprograms = load_programs(ARTICLE_ROOT / 'data' / 'programs.csv')\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'optimization_scenarios.csv')\nrows = enumerate_choices(programs, scenarios[0])\nbest_feasible(rows)
