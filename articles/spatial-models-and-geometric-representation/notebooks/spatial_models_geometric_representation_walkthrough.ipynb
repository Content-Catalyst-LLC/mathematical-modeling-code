# %% [markdown]
# # Spatial Models and Geometric Representation\n\nThis notebook demonstrates how geometry, distance, accessibility, and uncertainty review can be treated as explicit mathematical modeling objects.

# %% [markdown]
# $$p=(x,y)$$\n\n$$d(p_i,p_j)=\\sqrt{(x_i-x_j)^2+(y_i-y_j)^2}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom spatial_models_geometric_representation.core import load_locations, accessibility_rows\nlocations = load_locations(ARTICLE_ROOT / 'data' / 'spatial_locations.csv')\naccessibility_rows(locations)
