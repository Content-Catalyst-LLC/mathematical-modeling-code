# %% [markdown]
# # Sensitivity Analysis and Robustness\n\nThis notebook demonstrates how parameter ranges, one-at-a-time sweeps, sensitivity rankings, and threshold crossings can be treated as reproducible robustness artifacts.

# %% [markdown]
# $$S_i=\\frac{\\partial y}{\\partial x_i}$$\n\n$$E_i=\\frac{\\partial y}{\\partial x_i}\\cdot\\frac{x_i}{y}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom sensitivity_analysis_and_robustness.core import load_parameters, sweep_rows, sensitivity_summary\nparams = load_parameters(ARTICLE_ROOT / 'data' / 'sensitivity_parameters.csv')\nrows = sweep_rows(params)\nsensitivity_summary(rows)
