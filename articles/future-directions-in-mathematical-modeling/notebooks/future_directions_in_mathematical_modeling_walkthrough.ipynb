# %% [markdown]
# # Future Directions in Mathematical Modeling
#
# This notebook demonstrates future modeling direction registers, priority scores, governance needs, uncertainty briefs, human judgment protocols, and lifecycle artifacts.

# %% [markdown]
# $$\mathcal{M}=\{M_1,M_2,\ldots,M_k\}$$
#
# $$M_{t+1}=U(M_t,D_{t+1},E_{t+1},G_{t+1})$$

# %%
from pathlib import Path
import sys
ARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ARTICLE_ROOT / 'python'))
from future_directions_in_mathematical_modeling.core import load_future_modeling_directions, direction_priority, portfolio_summary
directions = load_future_modeling_directions(ARTICLE_ROOT / 'data' / 'future_modeling_directions.csv')
rows = [direction_priority(direction) for direction in directions]
portfolio_summary(rows)
