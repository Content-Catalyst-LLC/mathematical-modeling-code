# %% [markdown]
# # Diagnostics, Residuals, and Model Error\n\nThis notebook demonstrates how residuals, error metrics, group diagnostics, threshold disagreements, and outlier flags can be treated as reproducible diagnostic artifacts.

# %% [markdown]
# $$e_i = y_i - \\hat{y}_i$$\n\n$$RMSE=\\sqrt{\\frac{1}{n}\\sum_{i=1}^{n}e_i^2}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom diagnostics_residuals_model_error.core import load_observations, residual_rows, error_summary, group_summary\nobs = load_observations(ARTICLE_ROOT / 'data' / 'diagnostic_observations.csv')\nrows = residual_rows(obs)\n(error_summary(rows), group_summary(rows))
