# %% [markdown]
# # Model Boundaries, Scale, and Scope\n\nThis notebook demonstrates how model boundaries, scale, and scope can be represented as reviewable modeling artifacts.

# %% [markdown]
# $$M_{B,\\Delta}=S_\\Delta(M_B)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom boundary_scale_scope.core import load_scenarios, simulate_resource, summarize_resource\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'boundary_scenarios.csv')\nrows = simulate_resource(scenarios[0])\nsummarize_resource(rows)
