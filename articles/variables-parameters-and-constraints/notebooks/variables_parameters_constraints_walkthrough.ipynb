# %% [markdown]
# # Variables, Parameters, and Constraints
#
# Component-aware mathematical modeling workflow.

# %% [markdown]
# $$M=(V,P,A,R,C,O)$$
# $$S_{t+1}=\min(K,\max(0,S_t+I_t-D_t-\lambda S_t))$$
