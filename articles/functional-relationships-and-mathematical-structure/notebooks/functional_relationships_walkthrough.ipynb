# %% [markdown]
# # Functional Relationships and Mathematical Structure\n\nThis notebook demonstrates how functional relationships can be represented as reviewable structural choices.

# %% [markdown]
# $$O=M(X,\\Theta,A,C)$$\n\n$$S_{t+1}=\\min(K,\\max(0,S_t+I_t-D_t-\\lambda S_t))$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom functional_relationships_structure.core import load_scenarios, simulate_structure, summarize_structure\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'structure_scenarios.csv')\nrows = simulate_structure(scenarios[0])\nsummarize_structure(rows)
