# %% [markdown]
# # Dimensional Analysis, Units, and Scale\n\nThis notebook demonstrates how units, rates, time steps, and dimensionless ratios can be represented as reviewable model objects.

# %% [markdown]
# $$S_{t+1}=S_t+\\Delta t(I_t-D_t-\\lambda S_t)$$\n\n$$s_t=\\frac{S_t}{K}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom dimensional_analysis_units_scale.core import load_scale_scenarios, simulate_scale_scenario, summarize_scale_scenario\nscenarios = load_scale_scenarios(ARTICLE_ROOT / 'data' / 'scale_scenarios.csv')\nrows = simulate_scale_scenario(scenarios[0])\nsummarize_scale_scenario(rows)
