# %% [markdown]
# # Structural Uncertainty and Model Form Error\n\nThis notebook demonstrates how plausible model forms, structural spread, threshold disagreement, and review records can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$y=f_m(x,\\theta)$$\n\n$$\\mathcal{M}=\\{m_1,m_2,\\ldots,m_k\\}$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom structural_uncertainty_and_model_form_error.core import load_model_forms, comparison_rows, structural_summary\nforms = load_model_forms(ARTICLE_ROOT / 'data' / 'model_forms.csv')\nrows = comparison_rows(forms)\nstructural_summary(rows)
