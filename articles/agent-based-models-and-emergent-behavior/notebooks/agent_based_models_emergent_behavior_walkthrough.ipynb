# %% [markdown]
# # Agent-Based Models and Emergent Behavior\n\nThis notebook demonstrates how agent states, behavior rules, interaction structures, stochastic replications, and ensemble summaries can be treated as reviewable model objects.

# %% [markdown]
# $$S_{t+1}=F(S_t,A,E,\\theta,\\varepsilon_t)$$\n\n$$Y_t=M(S_t)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom agent_based_models_emergent_behavior.core import load_scenarios, run_replication, summarize_runs\nscenario = load_scenarios(ARTICLE_ROOT / 'data' / 'abm_scenarios.csv')[0]\nrows = run_replication(scenario, seed=1)\nrows[:3], summarize_runs(rows)
