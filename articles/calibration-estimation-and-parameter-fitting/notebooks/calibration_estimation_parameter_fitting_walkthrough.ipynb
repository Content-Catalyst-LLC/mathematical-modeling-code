# %% [markdown]
# # Calibration, Estimation, and Parameter Fitting\n\nThis notebook demonstrates how calibration data, parameter grids, objective functions, residual diagnostics, and audit cards can be treated as reproducible modeling artifacts.

# %% [markdown]
# $$\\hat{\\theta}=\\arg\\min_{\\theta} L(y,f(x;\\theta))$$\n\n$$S(\\theta)=\\sum_{i=1}^{n}(y_i-f(x_i;\\theta))^2$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom calibration_estimation_parameter_fitting.core import load_grid, load_observations, candidate_grid, fit_model\ndata = load_observations(ARTICLE_ROOT / 'data' / 'calibration_observations.csv')\ngrid = load_grid(ARTICLE_ROOT / 'data' / 'parameter_grid.csv')\nbest, scored = fit_model(data, candidate_grid(grid))\nbest
