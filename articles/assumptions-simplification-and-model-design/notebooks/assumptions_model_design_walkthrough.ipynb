# %% [markdown]
# # Assumptions, Simplification, and Model Design\n\nThis notebook demonstrates how assumptions, simplifications, and scenario tests can be represented as reviewable modeling artifacts.

# %% [markdown]
# $$S_{t+1}=\\min(K,\\max(0,S_t+I_t-D_t-L_t))$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom assumptions_model_design.core import load_scenarios, simulate_resource, summarize_resource\nscenarios = load_scenarios(ARTICLE_ROOT / 'data' / 'resource_scenarios.csv')\nrows = simulate_resource(scenarios[0])\nsummarize_resource(rows)
