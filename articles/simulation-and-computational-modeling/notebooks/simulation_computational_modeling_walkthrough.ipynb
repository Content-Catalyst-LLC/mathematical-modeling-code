# %% [markdown]
# # Simulation and Computational Modeling\n\nThis notebook demonstrates how simulation states, update rules, scenarios, random seeds, and ensemble outputs can be treated as reviewable model objects.

# %% [markdown]
# $$S_{t+1}=F(S_t,\\theta,u_t,\\varepsilon_t)$$\n\n$$Y=M(S_0,S_1,\\ldots,S_T)$$

# %%
from pathlib import Path\nimport sys\nARTICLE_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ARTICLE_ROOT / 'python'))\nfrom simulation_computational_modeling.core import load_scenarios, simulate, summarize\nscenario = load_scenarios(ARTICLE_ROOT / 'data' / 'simulation_scenarios.csv')[0]\nrows = simulate(scenario, seed=1)\nrows[:3], summarize(rows)
